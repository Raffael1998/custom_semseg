# %% [markdown]
# <a href="https://colab.research.google.com/github/Raffael1998/custom_semseg/blob/main/Custom_semantic_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Custom Semantic Segmentation
#
# Tutorial : https://github.com/Obsir/semantic-segmentation-framework-pytorch

# %%
# !git clone https://github.com/Obsir/semantic-segmentation-framework-pytorch
# Out:
# Cloning into 'semantic-segmentation-framework-pytorch'...
# remote: Enumerating objects: 229, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 229 (delta 24), reused 227 (delta 22), pack-reused 0
# Receiving objects: 100% (229/229), 383.23 KiB | 8.71 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/semantic-segmentation-framework-pytorch/requirements.txt

# %%
import os
import cv2
from google.colab.patches import cv2_imshow

# %%
path = '/content/drive/MyDrive/CARRS-Q internship/CARRS-Q - Dossier partagé/Databases/train _ Images reference Cityscape'
l = os.listdir(path)
path1 = os.path.join(path, l[1])
image = cv2.imread(path1)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1024 at 0x7F0D4F75BC90>

# %%
# !nnictl create --config /content/semantic-segmentation-framework-pytorch/nni_config.yml
# Out:
# [2022-05-17 00:38:50] INFO (numexpr.utils/MainThread) NumExpr defaulting to 2 threads.
# [2022-05-17 00:38:51] WARNING: Config field "authorName" is no longer supported and has been ignored
# [2022-05-17 00:38:51] WARNING: You are using legacy config file, please update it to latest format:
# ...
# experimentName: Pytorch-Segmentation
# trialConcurrency: 1
# maxExperimentDuration: 30d
# maxTrialNumber: 100
# searchSpaceFile: search_space.json
# useAnnotation: false
# trialCommand: python scripts/train_net.py
# trialCodeDirectory: .
# trialGpuNumber: 1
# tuner:
#   name: TPE
#   classArgs:
#     optimize_mode: maximize
# trainingService:
#   platform: local
# ...
# Reference: https://nni.readthedocs.io/en/stable/reference/experiment_config.html
# Traceback (most recent call last):
#   File "/usr/local/bin/nnictl", line 8, in <module>
#     sys.exit(parse_args())
#   File "/usr/local/lib/python3.7/dist-packages/nni/tools/nnictl/nnictl.py", line 497, in parse_args
#     args.func(args)
# ...

# %%
# !git init
# !git add /content/semantic-segmentation-framework-pytorch
# Out:
# Reinitialized existing Git repository in /content/.git/
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> semantic-segmentation-framework-pytorch
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached semantic-segmentation-framework-pytorch
# hint:
# hint: See "git help submodule" for more information.

# %%
# !git add /content/semantic-segmentation-framework-pytorch

# %%
# !git config --global user.email 'raffael.app@gmail.com' 
# !git config --global user.name 'Raffael1998'

# %%
# !git checkout master
# Out:
# M	semantic-segmentation-framework-pytorch
# Already on 'master'
# Your branch is up to date with 'origin/master'.

# %%
# !git remote -v
# Out:
# origin	https://Raffael1998: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@github.com/Raffael1998/custom_semseg.git (fetch)
# origin	https://Raffael1998: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@github.com/Raffael1998/custom_semseg.git (push)

# %%
# !git commit -m 'second commit'
# Out:
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Changes not staged for commit:
# 	modified:   semantic-segmentation-framework-pytorch (modified content, untracked content)
#
# Untracked files:
# 	.config/
# 	drive/
# 	sample_data/
#
# no changes added to commit

# %%
# !git remote set-url origin https://Raffael1998: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@github.com/Raffael1998/custom_semseg.git

# %%
# !git push -u origin master
# Out:
# Counting objects: 2, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 231 bytes | 231.00 KiB/s, done.
# Total 2 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/Raffael1998/custom_semseg/pull/new/master
# remote:
# To https://github.com/Raffael1998/custom_semseg.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
PROJ = '/content/semantic-segmentation-framework-pytorch'
GIT_USERNAME = "Raffael1998"
GIT_TOKEN = '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'
GIT_REPOSITORY = "custom_semseg"

PROJECT_PATH = PROJ

# %%
GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git"

# %%
# !mkdir ./temp
# !git clone "{GIT_PATH}"
# Out:
# mkdir: cannot create directory ‘./temp’: File exists
# Cloning into '{GIT_REPOSITORY}'...
# fatal: unable to access 'https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git/': The requested URL returned error: 400
